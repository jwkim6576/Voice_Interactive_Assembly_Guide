# %%
from ultralytics import settings

print(settings)
# Out:
# JSONDict("/home/rokey/.config/Ultralytics/settings.json"):
# {
#   "settings_version": "0.0.6",
#   "datasets_dir": "/home/rokey/ros2_ws/src/DoosanBootcampCol2/Tutorial/OD_Tutorial",
#   "weights_dir": "weights",
#   "runs_dir": "runs",
#   "uuid": "66b03edc808d1022df66573cacb0f641adb49ca4ee6b1677649c5b0eec8a39cf",
#   "sync": true,
#   "api_key": "",
#   "openai_api_key": "",
#   "clearml": true,
#   "comet": true,
#   "dvc": true,
#   "hub": true,
#   "mlflow": true,
#   "neptune": true,
#   "raytune": true,
#   "tensorboard": false,
#   "wandb": false,
#   "vscode_msg": true,
#   "openvino_msg": true
# }

# %%
from ultralytics import settings
settings.update({"datasets_dir": "/home/rokey/Downloads"})
print(settings['datasets_dir'])
# Out:
# /home/rokey/Downloads

# %%
settings.reset()
